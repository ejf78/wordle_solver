# %% [markdown]
# # Wordle Solver
#
# You can take a systematic approach to solving wordle puzzles. This is my attempt to write an algorithm that will efficiently solve wordle puzzles. Really, I am trying to figure out what the best starting words and strategies are.
#
# First, I'll work on an algorithm that can solve the puzzle, given an answer. I may later adapt this to interact with the wordle site and solve puzzles where the answer is truly unknown (in other words, an algorithm you could use to actually solve a puzzle).
#
# <b>Goal for the first Minimal Viable Product of this analysis: </b>
# - Write a function that can be fed a huge list of 5 letter words, and a list of starting words
#     - attempts to solve the wordle for each possible 5 letter answer in 6 attempts or fewer
#     - iterates over each starting word and each possible 5 letter answer
#     - tracks success rate and number of attempts for each starting word
# - visualize success of each starting word
#     - which words solved the puzzle quickest
#     - which words had the highest success rate
# - I may make multiple versions of the function that operate under different strategies and see which one had the best results on average

# %% [markdown]
# ### Wordle Solver (given the answer)

# %%
import pandas as pd
from english_words import english_words_lower_alpha_set as words # lower case letters, no punctuation

# %%
type(words)
len(words)
# Out:
# 25463

# %%
# create a dataframe from the set of words 
word_list = list(words)
word_df = pd.DataFrame(word_list).rename(columns = {0:"word"})

# %%
# add columns for info on words 
word_df['length'] = [len(w) for w in word_df.word]

# %%
# add count of unique letters 
word_df['unique_length'] = [len(set(word)) for word in word_df.word]

# %%
sample[0]
# Out:
# 'cecil'

# %%
set(sample[0])
# Out:
# {'c', 'e', 'i', 'l'}

# %%
'a' in set(sample[0]) or 'i' in set(sample[0])
# Out:
# True

# %%
[vowel for vowel in set(sample[0]) if vowel in ['a','e','i','o','u','y']]
# Out:
# ['e', 'i']

# %%
for sample_word in sample: 
    for letter in set(sample_word):
        if letter in ['a','e','i','o','u']: 
            letter

# %%
[letter for sample_word in sample for letter in set(sample_word) if letter in ['a','e','i','o','u']]
# Out:
# ['e', 'i', 'o', 'a', 'e', 'o', 'u', 'o', 'a', 'e', 'u', 'a']

# %%
def return_vowels(word):
    vowels = [letter for letter in set(word) if letter in ['a','e','i','o','u']]
    vowels.sort()
    return vowels

# %%
sample
# Out:
# ['cecil', 'gonad', 'joule', 'amoco', 'usage']

# %%
[return_vowels(word) for word in sample]
# Out:
# [['e', 'i'], ['a', 'o'], ['e', 'o', 'u'], ['a', 'o'], ['a', 'e', 'u']]

# %%
# add a few more helpful variables 
word_df["letters"] = [set(word) for word in word_df.word]
word_df["vowels"] = [return_vowels(word) for word in word_df.word]
word_df["vowel_count"] = [len(vowels) for vowels in word_df.vowels]

# %%
word_df
# Out:
#              word  length  unique_length                      letters  \
# 0               y       1              1                          {y}
# 1         diluent       7              7        {d, e, l, n, u, i, t}
# 2           cecil       5              4                 {c, e, l, i}
# 3        stricken       8              8     {c, e, n, k, s, i, r, t}
# 4         dragoon       7              6           {d, o, g, n, a, r}
# ...           ...     ...            ...                          ...
# 25458    bluebook       8              6           {e, l, o, b, u, k}
# 25459      codify       6              6           {c, d, y, f, o, i}
# 25460    airtight       8              6           {a, g, h, i, r, t}
# 25461      gibbon       6              5              {o, g, b, n, i}
# 25462  convulsive      10              9  {c, e, l, o, n, u, v, s, i}
#
#              vowels  vowel_count
# 0                []            0
# 1         [e, i, u]            3
# 2            [e, i]            2
# 3            [e, i]            2
# 4            [a, o]            2
# ...             ...          ...
# 25458     [e, o, u]            3
# 25459        [i, o]            2
# 25460        [a, i]            2
# 25461        [i, o]            2
# 25462  [e, i, o, u]            4
#
# [25463 rows x 6 columns]

# %%
# filter to just 5 letter words
word_df = word_df[word_df.length == 5]

# %%
[len(set(word)) for word in sample]
# Out:
# [4, 5, 5, 4, 5]

# %%
word_df
# Out:
#         word  length
# 2      cecil       5
# 5      gonad       5
# 9      joule       5
# 20     amoco       5
# 23     usage       5
# ...      ...     ...
# 25422  shoji       5
# 25443  fussy       5
# 25448  rabid       5
# 25452  stahl       5
# 25457  pasha       5
#
# [3213 rows x 2 columns]

# %% [markdown]
# Found some pre-written code defining the frequencies of each letter of the English alphabet:
# https://inventwithpython.com/hacking/chapter20.html
# However, I decided to update the values based on the dictionary frequency rather than frequency of letters in English texts. Words that rarely appear in text are totally fair game in Wordle!
# Frequency from: https://en.wikipedia.org/wiki/Letter_frequency

# %%
 englishLetterFreq = {'e': 11, 's':8.7,'i': 8.2, 'a': 7.8, 'r': 7.3, 'n': 7.2, 
                      't': 6.7, 'o': 6.1, 'l': 5.3, 'c': 4, 'd': 3.8, 'u': 3.3,
                      'g': 3, 'p': 2.8, 'm': 2.7, 'k': 2.5, 'h': 2.3, 'b': 2,
                      'y':1.6,'f': 1.4, 'v': 1, 'w': 0.91, 'z': 0.44, 'x': 0.27, 'q': 0.24, 'j': 0.21,
                     '.':0,'&':0}

# %%
def return_freqs(word):
    freq_list = [englishLetterFreq[letter] for letter in set(word)]
    return freq_list

# %%
sum([englishLetterFreq[letter] for letter in list(sample[0])])
# Out:
# 32.5

# %%
[return_freqs(word) for word in sample]
# Out:
# [[4, 11, 5.3, 8.2],
#  [3.8, 6.1, 3, 7.2, 7.8],
#  [11, 0.21, 5.3, 6.1, 3.3],
#  [6.1, 2.7, 7.8, 4],
#  [11, 3, 3.3, 8.7, 7.8]]

# %%
# add columns for word frequency (list and sum)
word_df["freq_list"] = [return_freqs(word) for word in word_df.word]
word_df["freq_sum"] = [sum(return_freqs(word)) for word in word_df.word]

# %%
sample
# Out:
# ['cecil', 'gonad', 'joule', 'amoco', 'usage']

# %%
word_df
# Out:
#                          word  length  unique_length  \
# 19422   immunoelectrophoresis      21             13
# 21012        neuropsychiatric      16             13
# 19608         ethnomusicology      15             13
# 8173   electroencephalography      22             12
# 3649     electroencephalogram      20             12
# ...                       ...     ...            ...
# 2523                        w       1              1
# 20516                       z       1              1
# 16521                       x       1              1
# 13050                       q       1              1
# 5440                        j       1              1
#
#                                        letters           vowels  vowel_count  \
# 19422  {c, e, p, l, o, m, n, h, u, s, i, r, t}     [e, i, o, u]            4
# 21012  {p, e, y, c, a, o, n, h, u, s, i, r, t}  [a, e, i, o, u]            5
# 19608  {c, e, y, l, o, m, g, n, h, u, s, i, t}     [e, i, o, u]            4
# 8173      {c, e, p, y, l, o, g, n, h, a, r, t}        [a, e, o]            3
# 3649      {c, e, p, l, o, g, m, n, h, a, r, t}        [a, e, o]            3
# ...                                        ...              ...          ...
# 2523                                       {w}               []            0
# 20516                                      {z}               []            0
# 16521                                      {x}               []            0
# 13050                                      {q}               []            0
# 5440                                       {j}               []            0
#
#                                                freq_list  freq_sum
# 19422  [4, 11, 2.8, 5.3, 6.1, 2.7, 7.2, 2.3, 3.3, 8.7...     75.60
# 21012  [2.8, 11, 1.6, 4, 7.8, 6.1, 7.2, 2.3, 3.3, 8.7...     77.00
# 19608  [4, 11, 1.6, 5.3, 6.1, 2.7, 3, 7.2, 2.3, 3.3, ...     70.10
# 8173   [4, 11, 2.8, 1.6, 5.3, 6.1, 3, 7.2, 2.3, 7.8, ...     65.10
# 3649   [4, 11, 2.8, 5.3, 6.1, 3, 2.7, 7.2, 2.3, 7.8, ...     66.20
# ...                                                  ...       ...
# 2523                                              [0.91]      0.91
# 20516                                             [0.44]      0.44
# 16521                                             [0.27]      0.27
# 13050                                             [0.24]      0.24
# 5440                                              [0.21]      0.21
#
# [25463 rows x 8 columns]

# %%
# sort values
word_df = word_df.sort_values(["unique_length","freq_sum"], ascending = (False, False))

# %%
# now filter to 5 letter words
word5 = word_df[word_df.length == 5].copy()

# %%
word5 # this is pretty cool to see!
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 435    arise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14482  aries       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14573  aires       5              5  {e, a, s, i, r}  [a, e, i]            3
# 17505  raise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 12052  anise       5              5  {e, a, n, s, i}  [a, e, i]            3
# ...      ...     ...            ...              ...        ...          ...
# 7223   puppy       5              3        {p, y, u}        [u]            1
# 12766  mummy       5              3        {y, m, u}        [u]            1
# 19056  beebe       5              2           {e, b}        [e]            1
# 17840  mamma       5              2           {m, a}        [a]            1
# 61     ababa       5              2           {b, a}        [a]            1
#
#                       freq_list  freq_sum
# 435    [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 14482  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 14573  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 17505  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 12052  [11, 7.8, 7.2, 8.7, 8.2]      42.9
# ...                         ...       ...
# 7223            [2.8, 1.6, 3.3]       7.7
# 12766           [1.6, 2.7, 3.3]       7.6
# 19056                   [11, 2]      13.0
# 17840                [2.7, 7.8]      10.5
# 61                     [2, 7.8]       9.8
#
# [3213 rows x 8 columns]

# %%
word5.head(20)
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 435    arise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14482  aries       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14573  aires       5              5  {e, a, s, i, r}  [a, e, i]            3
# 17505  raise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 12052  anise       5              5  {e, a, n, s, i}  [a, e, i]            3
# 10735  siena       5              5  {e, n, s, i, a}  [a, e, i]            3
# 12313  risen       5              5  {e, n, s, i, r}     [e, i]            2
# 14087  siren       5              5  {e, n, s, i, r}     [e, i]            2
# 18578  rinse       5              5  {e, n, s, i, r}     [e, i]            2
# 3031   snare       5              5  {e, n, s, a, r}     [a, e]            2
# 2289   stein       5              5  {e, n, s, i, t}     [e, i]            2
# 8349   inset       5              5  {e, n, s, i, t}     [e, i]            2
# 3238   aster       5              5  {e, s, a, r, t}     [a, e]            2
# 15160  stare       5              5  {e, s, a, r, t}     [a, e]            2
# 6210   osier       5              5  {e, o, s, i, r}  [e, i, o]            3
# 6364   noise       5              5  {e, o, n, s, i}  [e, i, o]            3
# 1044   artie       5              5  {e, a, i, r, t}  [a, e, i]            3
# 18117  irate       5              5  {e, i, a, r, t}  [a, e, i]            3
# 24103  aisle       5              5  {e, l, a, s, i}  [a, e, i]            3
# 4607   ernst       5              5  {e, n, s, r, t}        [e]            1
#
#                       freq_list  freq_sum
# 435    [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 14482  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 14573  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 17505  [11, 7.8, 8.7, 8.2, 7.3]      43.0
# 12052  [11, 7.8, 7.2, 8.7, 8.2]      42.9
# 10735  [11, 7.2, 8.7, 8.2, 7.8]      42.9
# 12313  [11, 7.2, 8.7, 8.2, 7.3]      42.4
# 14087  [11, 7.2, 8.7, 8.2, 7.3]      42.4
# 18578  [11, 7.2, 8.7, 8.2, 7.3]      42.4
# 3031   [11, 7.2, 8.7, 7.8, 7.3]      42.0
# 2289   [11, 7.2, 8.7, 8.2, 6.7]      41.8
# 8349   [11, 7.2, 8.7, 8.2, 6.7]      41.8
# 3238   [11, 8.7, 7.8, 7.3, 6.7]      41.5
# 15160  [11, 8.7, 7.8, 7.3, 6.7]      41.5
# 6210   [11, 6.1, 8.7, 8.2, 7.3]      41.3
# 6364   [11, 6.1, 7.2, 8.7, 8.2]      41.2
# 1044   [11, 7.8, 8.2, 7.3, 6.7]      41.0
# 18117  [11, 8.2, 7.8, 7.3, 6.7]      41.0
# 24103  [11, 5.3, 7.8, 8.7, 8.2]      41.0
# 4607   [11, 7.2, 8.7, 7.3, 6.7]      40.9

# %%
[word[0] for word in sample]
# Out:
# ['c', 'g', 'j', 'a', 'u']

# %%
sample
# Out:
# ['cecil', 'gonad', 'joule', 'amoco', 'usage']

# %%
# add variables for each letter, by position 
word5["letter1"] = [word[0] for word in word5.word]
word5["letter2"] = [word[1] for word in word5.word]
word5["letter3"] = [word[2] for word in word5.word]
word5["letter4"] = [word[3] for word in word5.word]
word5["letter5"] = [word[4] for word in word5.word]
word5
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 435    arise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14482  aries       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14573  aires       5              5  {e, a, s, i, r}  [a, e, i]            3
# 17505  raise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 12052  anise       5              5  {e, a, n, s, i}  [a, e, i]            3
# ...      ...     ...            ...              ...        ...          ...
# 7223   puppy       5              3        {p, y, u}        [u]            1
# 12766  mummy       5              3        {y, m, u}        [u]            1
# 19056  beebe       5              2           {e, b}        [e]            1
# 17840  mamma       5              2           {m, a}        [a]            1
# 61     ababa       5              2           {b, a}        [a]            1
#
#                       freq_list  freq_sum letter1 letter2 letter3 letter4  \
# 435    [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       r       i       s
# 14482  [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       r       i       e
# 14573  [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       i       r       e
# 17505  [11, 7.8, 8.7, 8.2, 7.3]      43.0       r       a       i       s
# 12052  [11, 7.8, 7.2, 8.7, 8.2]      42.9       a       n       i       s
# ...                         ...       ...     ...     ...     ...     ...
# 7223            [2.8, 1.6, 3.3]       7.7       p       u       p       p
# 12766           [1.6, 2.7, 3.3]       7.6       m       u       m       m
# 19056                   [11, 2]      13.0       b       e       e       b
# 17840                [2.7, 7.8]      10.5       m       a       m       m
# 61                     [2, 7.8]       9.8       a       b       a       b
#
#       letter5
# 435         e
# 14482       s
# 14573       s
# 17505       e
# 12052       e
# ...       ...
# 7223        y
# 12766       y
# 19056       e
# 17840       a
# 61          a
#
# [3213 rows x 13 columns]

# %% [markdown]
# ### Solving a Wordle
#
# Working towards a function that can try out a word, get feedback, and work towards the puzzle solution.

# %%
# example: answer = "spare", starting word - "arise"

answer = "spare"
start = "arise"

# %%
# check if any letters are in the right position 
correct_position = [start[n] == answer[n] for n in range(0,5)]
correct_position
# Out:
# [False, False, False, False, True]

# %%
correct_position = [n for n in range(0,5) if start[n] == answer[n]]

# %%
n = 0
"letter" + str(n + 1)
# Out:
# 'letter1'

# %%
start[0] not in answer
# Out:
# False

# %%
words_to_consider[~words_to_consider.word.str.contains('i')]
# Out:
#     index   word  length  unique_length          letters  vowels  vowel_count  \
# 0   25140  front       5              5  {f, o, n, r, t}     [o]            1
# 1    1653  grunt       5              5  {g, n, u, r, t}     [u]            1
# 2   22832  trunk       5              5  {n, u, k, r, t}     [u]            1
# 3   16703  brunt       5              5  {b, n, u, r, t}     [u]            1
# 4   22919  grout       5              5  {o, g, u, r, t}  [o, u]            2
# 5   23956  prong       5              5  {p, o, g, n, r}     [o]            1
# 6   10634  crony       5              5  {c, y, o, n, r}     [o]            1
# 7    3541  bruno       5              5  {o, b, n, u, r}  [o, u]            2
# 8   18915  frond       5              5  {d, f, o, n, r}     [o]            1
# 9   20508  crown       5              5  {c, o, w, n, r}     [o]            1
# 10   4817  croft       5              5  {c, f, o, r, t}     [o]            1
# 11  17746  drown       5              5  {d, o, w, n, r}     [o]            1
# 12  17669  grown       5              5  {o, g, w, n, r}     [o]            1
# 13  18046  wrong       5              5  {w, o, g, n, r}     [o]            1
# 14   8134  broth       5              5  {o, b, h, r, t}     [o]            1
# 15  10014  truly       5              5  {y, l, u, r, t}     [u]            1
# 16    481  drunk       5              5  {d, n, u, k, r}     [u]            1
# 17   2623  truck       5              5  {c, u, k, r, t}     [u]            1
# 18  20896  froth       5              5  {f, o, h, r, t}     [o]            1
# 19   4675  brown       5              5  {o, w, b, n, r}     [o]            1
# 20  17599  proud       5              5  {p, d, o, u, r}  [o, u]            2
# 21  22298  frown       5              5  {f, o, w, n, r}     [o]            1
# 22   8312  bronx       5              5  {o, b, n, x, r}     [o]            1
# 23  14030  trump       5              5  {p, m, u, r, t}     [u]            1
# 24  16324  trudy       5              5  {d, y, u, r, t}     [u]            1
# 25  21503  growl       5              5  {l, o, g, w, r}     [o]            1
# 26   5892  group       5              5  {p, o, g, u, r}  [o, u]            2
# 27  20674  prowl       5              5  {p, l, o, w, r}     [o]            1
# 28  23914  crypt       5              5  {c, y, p, r, t}      []            0
# 29  24869  crowd       5              5  {c, d, o, w, r}     [o]            1
# 30  11279  brock       5              5  {c, o, b, k, r}     [o]            1
# 31  14621  frock       5              5  {c, f, o, k, r}     [o]            1
# 32   7875  crump       5              5  {c, p, m, u, r}     [u]            1
# 33  18853  crumb       5              5  {c, m, b, u, r}     [u]            1
# 34   7659  grump       5              5  {p, g, m, u, r}     [u]            1
# 35  19485  proxy       5              5  {p, y, o, x, r}     [o]            1
# 36   8074  troll       5              4     {o, l, r, t}     [o]            1
# 37  12810  croon       5              4     {c, o, n, r}     [o]            1
# 38  17571  trout       5              4     {o, u, r, t}  [o, u]            2
# 39  13720  troop       5              4     {o, p, r, t}     [o]            1
# 40   9657  proto       5              4     {p, o, r, t}     [o]            1
# 41   5857  drool       5              4     {d, o, l, r}     [o]            1
# 42  14861  droll       5              4     {d, o, l, r}     [o]            1
# 43  18982  nroff       5              4     {o, f, n, r}     [o]            1
# 44   6159  troff       5              4     {o, f, r, t}     [o]            1
# 45    769  droop       5              4     {d, o, p, r}     [o]            1
# 46  17749  crook       5              4     {c, o, r, k}     [o]            1
# 47   2070  crock       5              4     {c, o, r, k}     [o]            1
# 48   1057  truth       5              4     {h, u, r, t}     [u]            1
# 49  25341  brood       5              4     {o, d, b, r}     [o]            1
# 50  16960  groom       5              4     {o, g, m, r}     [o]            1
# 51    493  broom       5              4     {o, m, b, r}     [o]            1
# 52   2305  brook       5              4     {o, b, r, k}     [o]            1
# 53  17041  proof       5              4     {p, o, f, r}     [o]            1
# 54  23307  drury       5              4     {d, y, u, r}     [u]            1
# 55  17608  gruff       5              4     {g, f, u, r}     [u]            1
# 56  23301  orono       5              3        {o, n, r}     [o]            1
#
#                      freq_list  freq_sum letter1 letter2 letter3 letter4  \
# 0    [1.4, 6.1, 7.2, 7.3, 6.7]     28.70       f       r       o       n
# 1      [3, 7.2, 3.3, 7.3, 6.7]     27.50       g       r       u       n
# 2    [7.2, 3.3, 2.5, 7.3, 6.7]     27.00       t       r       u       n
# 3      [2, 7.2, 3.3, 7.3, 6.7]     26.50       b       r       u       n
# 4      [6.1, 3, 3.3, 7.3, 6.7]     26.40       g       r       o       u
# 5      [2.8, 6.1, 3, 7.2, 7.3]     26.40       p       r       o       n
# 6      [4, 1.6, 6.1, 7.2, 7.3]     26.20       c       r       o       n
# 7      [6.1, 2, 7.2, 3.3, 7.3]     25.90       b       r       u       n
# 8    [3.8, 1.4, 6.1, 7.2, 7.3]     25.80       f       r       o       n
# 9     [4, 6.1, 0.91, 7.2, 7.3]     25.51       c       r       o       w
# 10     [4, 1.4, 6.1, 7.3, 6.7]     25.50       c       r       o       f
# 11  [3.8, 6.1, 0.91, 7.2, 7.3]     25.31       d       r       o       w
# 12    [6.1, 3, 0.91, 7.2, 7.3]     24.51       g       r       o       w
# 13    [0.91, 6.1, 3, 7.2, 7.3]     24.51       w       r       o       n
# 14     [6.1, 2, 2.3, 7.3, 6.7]     24.40       b       r       o       t
# 15   [1.6, 5.3, 3.3, 7.3, 6.7]     24.20       t       r       u       l
# 16   [3.8, 7.2, 3.3, 2.5, 7.3]     24.10       d       r       u       n
# 17     [4, 3.3, 2.5, 7.3, 6.7]     23.80       t       r       u       c
# 18   [1.4, 6.1, 2.3, 7.3, 6.7]     23.80       f       r       o       t
# 19    [6.1, 0.91, 2, 7.2, 7.3]     23.51       b       r       o       w
# 20   [2.8, 3.8, 6.1, 3.3, 7.3]     23.30       p       r       o       u
# 21  [1.4, 6.1, 0.91, 7.2, 7.3]     22.91       f       r       o       w
# 22    [6.1, 2, 7.2, 0.27, 7.3]     22.87       b       r       o       n
# 23   [2.8, 2.7, 3.3, 7.3, 6.7]     22.80       t       r       u       m
# 24   [3.8, 1.6, 3.3, 7.3, 6.7]     22.70       t       r       u       d
# 25    [5.3, 6.1, 3, 0.91, 7.3]     22.61       g       r       o       w
# 26     [2.8, 6.1, 3, 3.3, 7.3]     22.50       g       r       o       u
# 27  [2.8, 5.3, 6.1, 0.91, 7.3]     22.41       p       r       o       w
# 28     [4, 1.6, 2.8, 7.3, 6.7]     22.40       c       r       y       p
# 29    [4, 3.8, 6.1, 0.91, 7.3]     22.11       c       r       o       w
# 30       [4, 6.1, 2, 2.5, 7.3]     21.90       b       r       o       c
# 31     [4, 1.4, 6.1, 2.5, 7.3]     21.30       f       r       o       c
# 32     [4, 2.8, 2.7, 3.3, 7.3]     20.10       c       r       u       m
# 33       [4, 2.7, 2, 3.3, 7.3]     19.30       c       r       u       m
# 34     [2.8, 3, 2.7, 3.3, 7.3]     19.10       g       r       u       m
# 35  [2.8, 1.6, 6.1, 0.27, 7.3]     18.07       p       r       o       x
# 36        [6.1, 5.3, 7.3, 6.7]     25.40       t       r       o       l
# 37          [4, 6.1, 7.2, 7.3]     24.60       c       r       o       o
# 38        [6.1, 3.3, 7.3, 6.7]     23.40       t       r       o       u
# 39        [6.1, 2.8, 7.3, 6.7]     22.90       t       r       o       o
# 40        [2.8, 6.1, 7.3, 6.7]     22.90       p       r       o       t
# 41        [3.8, 6.1, 5.3, 7.3]     22.50       d       r       o       o
# 42        [3.8, 6.1, 5.3, 7.3]     22.50       d       r       o       l
# 43        [6.1, 1.4, 7.2, 7.3]     22.00       n       r       o       f
# 44        [6.1, 1.4, 7.3, 6.7]     21.50       t       r       o       f
# 45        [3.8, 6.1, 2.8, 7.3]     20.00       d       r       o       o
# 46          [4, 6.1, 7.3, 2.5]     19.90       c       r       o       o
# 47          [4, 6.1, 7.3, 2.5]     19.90       c       r       o       c
# 48        [2.3, 3.3, 7.3, 6.7]     19.60       t       r       u       t
# 49          [6.1, 3.8, 2, 7.3]     19.20       b       r       o       o
# 50          [6.1, 3, 2.7, 7.3]     19.10       g       r       o       o
# 51          [6.1, 2.7, 2, 7.3]     18.10       b       r       o       o
# 52          [6.1, 2, 7.3, 2.5]     17.90       b       r       o       o
# 53        [2.8, 6.1, 1.4, 7.3]     17.60       p       r       o       o
# 54        [3.8, 1.6, 3.3, 7.3]     16.00       d       r       u       r
# 55          [3, 1.4, 3.3, 7.3]     15.00       g       r       u       f
# 56             [6.1, 7.2, 7.3]     20.60       o       r       o       n
#
#    letter5
# 0        t
# 1        t
# 2        k
# 3        t
# 4        t
# 5        g
# 6        y
# 7        o
# 8        d
# 9        n
# 10       t
# 11       n
# 12       n
# 13       g
# 14       h
# 15       y
# 16       k
# 17       k
# 18       h
# 19       n
# 20       d
# 21       n
# 22       x
# 23       p
# 24       y
# 25       l
# 26       p
# 27       l
# 28       t
# 29       d
# 30       k
# 31       k
# 32       p
# 33       b
# 34       p
# 35       y
# 36       l
# 37       n
# 38       t
# 39       p
# 40       o
# 41       l
# 42       l
# 43       f
# 44       f
# 45       p
# 46       k
# 47       k
# 48       h
# 49       d
# 50       m
# 51       m
# 52       k
# 53       f
# 54       y
# 55       f
# 56       o

# %%
words_to_consider = word5.copy()
if start == answer: 
    print(f"The answer is {start}")
else:
    for n in range(0,5):
        if start[n] == answer[n]:
            col = "letter" + str(n + 1)
            words_to_consider = words_to_consider[words_to_consider[col] == start[n]]
        elif start[n] not in answer: 
            words_to_consider = words_to_consider[~words_to_consider.word.str.contains(start[n])]
        else: # letter is in the answer, but not in the right place 
            words_to_consider = words_to_consider[words_to_consider.word.str.contains(start[n])]
    words_to_consider = words_to_consider.reset_index()

# %%
word5
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 435    arise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14482  aries       5              5  {e, a, s, i, r}  [a, e, i]            3
# 14573  aires       5              5  {e, a, s, i, r}  [a, e, i]            3
# 17505  raise       5              5  {e, a, s, i, r}  [a, e, i]            3
# 12052  anise       5              5  {e, a, n, s, i}  [a, e, i]            3
# ...      ...     ...            ...              ...        ...          ...
# 7223   puppy       5              3        {p, y, u}        [u]            1
# 12766  mummy       5              3        {y, m, u}        [u]            1
# 19056  beebe       5              2           {e, b}        [e]            1
# 17840  mamma       5              2           {m, a}        [a]            1
# 61     ababa       5              2           {b, a}        [a]            1
#
#                       freq_list  freq_sum letter1 letter2 letter3 letter4  \
# 435    [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       r       i       s
# 14482  [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       r       i       e
# 14573  [11, 7.8, 8.7, 8.2, 7.3]      43.0       a       i       r       e
# 17505  [11, 7.8, 8.7, 8.2, 7.3]      43.0       r       a       i       s
# 12052  [11, 7.8, 7.2, 8.7, 8.2]      42.9       a       n       i       s
# ...                         ...       ...     ...     ...     ...     ...
# 7223            [2.8, 1.6, 3.3]       7.7       p       u       p       p
# 12766           [1.6, 2.7, 3.3]       7.6       m       u       m       m
# 19056                   [11, 2]      13.0       b       e       e       b
# 17840                [2.7, 7.8]      10.5       m       a       m       m
# 61                     [2, 7.8]       9.8       a       b       a       b
#
#       letter5
# 435         e
# 14482       s
# 14573       s
# 17505       e
# 12052       e
# ...       ...
# 7223        y
# 12766       y
# 19056       e
# 17840       a
# 61          a
#
# [3213 rows x 13 columns]

# %%
# choose the next word to try 
next_word = words_to_consider["word"][0]
next_word
# Out:
# 'snare'

# %%
# putting it all in 1 loop 
answer = "birth"
guess = "miner"
guesses = []
attempt_no = 1
words_to_consider = word5.copy()

while attempt_no <= 6:
    guesses.append(guess)
    if guess == answer:
        print(f"The answer is {guess}, found in attempt number {attempt_no}")
        print(f"Guesses: {guesses}")
        break
    elif attempt_no <= 5: 
        for n in range(0,5):
            col = "letter" + str(n + 1)
            if guess[n] == answer[n]: # letter is in the right place 
                words_to_consider = words_to_consider[words_to_consider[col] == guess[n]]
            elif guess[n] not in answer: # letter not in the answer
                words_to_consider = words_to_consider[~words_to_consider.word.str.contains(guess[n])]
             #   print(f"Dropped words containing {guess[n]}")
            else: # letter is in the answer, but not in the right place 
                words_to_consider = words_to_consider[words_to_consider.word.str.contains(guess[n])]
                # and drop words that have this letter in this exact position 
                words_to_consider = words_to_consider[words_to_consider[col] != guess[n]]
               # print(f"Filtered to words containing {guess[n]}, but where {col} is not {guess[n]}")
        words_to_consider = words_to_consider.reset_index(drop = True)
      #  print(f"This was attempt {attempt_no}")
        guess = words_to_consider["word"][0]
        attempt_no = attempt_no + 1
    else: 
        print("Sorry, couldn't do it :(")
        print(f"Guesses: {guesses}")
# Out:
# The answer is birth, found in attempt number 5
# Guesses: ['miner', 'first', 'dirty', 'girth', 'birth']

# %%
# final function! 
def wordle(answer, guess):
    guesses = []
    attempt_no = 1
    words_to_consider = word5.copy()

    while attempt_no <= 6:
        guesses.append(guess)
        if guess == answer:
            print(f"The answer is {guess}, found in attempt number {attempt_no}")
            print(f"Guesses: {guesses}")
            break
        elif attempt_no <= 5: 
            for n in range(0,5):
                col = "letter" + str(n + 1)
                if guess[n] == answer[n]: # letter is in the right place 
                    words_to_consider = words_to_consider[words_to_consider[col] == guess[n]]
                elif guess[n] not in answer: # letter not in the answer
                    words_to_consider = words_to_consider[~words_to_consider.word.str.contains(guess[n])]
                 #   print(f"Dropped words containing {guess[n]}")
                else: # letter is in the answer, but not in the right place 
                    words_to_consider = words_to_consider[words_to_consider.word.str.contains(guess[n])]
                    # and drop words that have this letter in this exact position 
                    words_to_consider = words_to_consider[words_to_consider[col] != guess[n]]
                   # print(f"Filtered to words containing {guess[n]}, but where {col} is not {guess[n]}")
            words_to_consider = words_to_consider.reset_index(drop = True)
          #  print(f"This was attempt {attempt_no}")
            guess = words_to_consider["word"][0]
            attempt_no = attempt_no + 1
        else: 
            print("Sorry, couldn't do it :(")
            print(f"Guesses: {guesses}")

# %%
wordle(answer = "brick", guess = "stuck")
# Out:
# The answer is brick, found in attempt number 4
# Guesses: ['stuck', 'aleck', 'prick', 'brick']

# %%
wordle(answer = "prick", guess = "stuck")
# Out:
# The answer is prick, found in attempt number 3
# Guesses: ['stuck', 'aleck', 'prick']

# %%
wordle(answer = "shire", guess = "brink")
# Out:
# The answer is shire, found in attempt number 4
# Guesses: ['brink', 'raise', 'spire', 'shire']

# %%
wordle(answer = "robot", guess = "brink")
# Out:
# The answer is robot, found in attempt number 4
# Guesses: ['brink', 'sober', 'cobra', 'robot']

# %%
wordle(answer = "robot", guess = "audio")
# Out:
# The answer is robot, found in attempt number 4
# Guesses: ['audio', 'senor', 'throb', 'robot']
