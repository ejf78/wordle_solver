# %% [markdown]
# # Wordle Solver
#
# You can take a systematic approach to solving wordle puzzles. This is my attempt to write an algorithm that will efficiently solve wordle puzzles. Really, I am trying to figure out what the best starting words and strategies are.
#
# First, I'll work on an algorithm that can solve the puzzle, given an answer. I may later adapt this to interact with the wordle site and solve puzzles where the answer is truly unknown (in other words, an algorithm you could use to actually solve a puzzle).
#
# <b>Goal for the first Minimal Viable Product of this analysis: </b>
# - Write a function that can be fed a huge list of 5 letter words, and a list of starting words
#     - attempts to solve the wordle for each possible 5 letter answer in 6 attempts or fewer
#     - iterates over each starting word and each possible 5 letter answer
#     - tracks success rate and number of attempts for each starting word
# - visualize success of each starting word
#     - which words solved the puzzle quickest
#     - which words had the highest success rate
# - I may make multiple versions of the function that operate under different strategies and see which one had the best results on average
#
#
#
# Found a helpful article for hosting a python app for free: https://towardsdatascience.com/the-easiest-way-to-deploy-your-dash-app-for-free-f92c575bb69e

# %% [markdown]
# ### Wordle Solver (given the answer)

# %%
import pandas as pd
import numpy as np
from english_words import english_words_lower_alpha_set as words # lower case letters, no punctuation

# %%
# create a dataframe from the set of words 
word_list = list(words)
word_df = pd.DataFrame(word_list).rename(columns = {0:"word"})

# %%
# add columns for info on words 
word_df['length'] = [len(w) for w in word_df.word]

# %%
# add count of unique letters 
word_df['unique_length'] = [len(set(word)) for word in word_df.word]

# %%
def return_vowels(word):
    vowels = [letter for letter in set(word) if letter in ['a','e','i','o','u']]
    vowels.sort()
    return vowels

# %%
# add a few more helpful variables 
word_df["letters"] = [set(word) for word in word_df.word]
word_df["vowels"] = [return_vowels(word) for word in word_df.word]
word_df["vowel_count"] = [len(vowels) for vowels in word_df.vowels]

# %%
word_df
# Out:
#                word  length  unique_length                         letters  \
# 0           thereby       7              6              {t, h, y, e, b, r}
# 1           willful       7              5                 {w, u, l, f, i}
# 2             parsi       5              5                 {r, a, p, i, s}
# 3            seabed       6              5                 {a, e, b, d, s}
# 4         commodity       9              7           {m, o, t, y, i, c, d}
# ...             ...     ...            ...                             ...
# 25458   picturesque      11              9     {s, q, u, t, e, p, i, c, r}
# 25459        gerbil       6              6              {l, e, b, i, g, r}
# 25460  childrearing      12             10  {l, h, a, e, n, g, i, c, d, r}
# 25461    footbridge      10              9     {o, t, f, e, g, b, i, d, r}
# 25462    intestinal      10              7           {t, a, l, e, n, i, s}
#
#           vowels  vowel_count
# 0            [e]            1
# 1         [i, u]            2
# 2         [a, i]            2
# 3         [a, e]            2
# 4         [i, o]            2
# ...          ...          ...
# 25458  [e, i, u]            3
# 25459     [e, i]            2
# 25460  [a, e, i]            3
# 25461  [e, i, o]            3
# 25462  [a, e, i]            3
#
# [25463 rows x 6 columns]

# %% [markdown]
# Found some pre-written code defining the frequencies of each letter of the English alphabet:
# https://inventwithpython.com/hacking/chapter20.html
# However, I decided to update the values based on the dictionary frequency rather than frequency of letters in English texts. Words that rarely appear in text are totally fair game in Wordle!
# Frequency from: https://en.wikipedia.org/wiki/Letter_frequency

# %%
 englishLetterFreq = {'e': 11, 's':8.7,'i': 8.2, 'a': 7.8, 'r': 7.3, 'n': 7.2, 
                      't': 6.7, 'o': 6.1, 'l': 5.3, 'c': 4, 'd': 3.8, 'u': 3.3,
                      'g': 3, 'p': 2.8, 'm': 2.7, 'k': 2.5, 'h': 2.3, 'b': 2,
                      'y':1.6,'f': 1.4, 'v': 1, 'w': 0.91, 'z': 0.44, 'x': 0.27, 'q': 0.24, 'j': 0.21,
                     '.':0,'&':0}

# %%
def return_freqs(word):
    freq_list = [englishLetterFreq[letter] for letter in set(word)]
    return freq_list

# %%
# add columns for word frequency (list and sum)
word_df["freq_list"] = [return_freqs(word) for word in word_df.word]
word_df["freq_sum"] = [sum(return_freqs(word)) for word in word_df.word]

# %%
# sort values
word_df = word_df.sort_values(["unique_length","freq_sum"], ascending = (False, False))

# %%
# now filter to 5 letter words
word5 = word_df[word_df.length == 5].copy()

# %%
word5 # this is pretty cool to see!
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 4000   aires       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12338  arise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12809  aries       5              5  {r, a, e, i, s}  [a, e, i]            3
# 15519  raise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 1577   siena       5              5  {a, e, n, i, s}  [a, e, i]            3
# ...      ...     ...            ...              ...        ...          ...
# 3972   puppy       5              3        {p, y, u}        [u]            1
# 16727  mummy       5              3        {m, y, u}        [u]            1
# 24887  beebe       5              2           {e, b}        [e]            1
# 15601  mamma       5              2           {a, m}        [a]            1
# 431    ababa       5              2           {a, b}        [a]            1
#
#                       freq_list  freq_sum
# 4000   [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 12338  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 12809  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 15519  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 1577   [7.8, 11, 7.2, 8.2, 8.7]      42.9
# ...                         ...       ...
# 3972            [2.8, 1.6, 3.3]       7.7
# 16727           [2.7, 1.6, 3.3]       7.6
# 24887                   [11, 2]      13.0
# 15601                [7.8, 2.7]      10.5
# 431                    [7.8, 2]       9.8
#
# [3213 rows x 8 columns]

# %%
word5.head(20)
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 4000   aires       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12338  arise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12809  aries       5              5  {r, a, e, i, s}  [a, e, i]            3
# 15519  raise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 1577   siena       5              5  {a, e, n, i, s}  [a, e, i]            3
# 4291   anise       5              5  {a, e, n, i, s}  [a, e, i]            3
# 951    risen       5              5  {r, e, n, i, s}     [e, i]            2
# 4280   rinse       5              5  {r, e, n, i, s}     [e, i]            2
# 5649   siren       5              5  {s, e, n, i, r}     [e, i]            2
# 16596  snare       5              5  {s, a, e, n, r}     [a, e]            2
# 1902   inset       5              5  {t, e, n, i, s}     [e, i]            2
# 11632  stein       5              5  {t, e, n, i, s}     [e, i]            2
# 14538  stare       5              5  {s, t, a, e, r}     [a, e]            2
# 15894  aster       5              5  {s, t, a, e, r}     [a, e]            2
# 20050  osier       5              5  {s, o, e, i, r}  [e, i, o]            3
# 10575  noise       5              5  {o, e, n, i, s}  [e, i, o]            3
# 10663  irate       5              5  {t, a, e, i, r}  [a, e, i]            3
# 21900  artie       5              5  {t, a, e, i, r}  [a, e, i]            3
# 22227  aisle       5              5  {a, l, e, i, s}  [a, e, i]            3
# 17016  ernst       5              5  {r, t, e, n, s}        [e]            1
#
#                       freq_list  freq_sum
# 4000   [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 12338  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 12809  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 15519  [7.3, 7.8, 11, 8.2, 8.7]      43.0
# 1577   [7.8, 11, 7.2, 8.2, 8.7]      42.9
# 4291   [7.8, 11, 7.2, 8.2, 8.7]      42.9
# 951    [7.3, 11, 7.2, 8.2, 8.7]      42.4
# 4280   [7.3, 11, 7.2, 8.2, 8.7]      42.4
# 5649   [8.7, 11, 7.2, 8.2, 7.3]      42.4
# 16596  [8.7, 7.8, 11, 7.2, 7.3]      42.0
# 1902   [6.7, 11, 7.2, 8.2, 8.7]      41.8
# 11632  [6.7, 11, 7.2, 8.2, 8.7]      41.8
# 14538  [8.7, 6.7, 7.8, 11, 7.3]      41.5
# 15894  [8.7, 6.7, 7.8, 11, 7.3]      41.5
# 20050  [8.7, 6.1, 11, 8.2, 7.3]      41.3
# 10575  [6.1, 11, 7.2, 8.2, 8.7]      41.2
# 10663  [6.7, 7.8, 11, 8.2, 7.3]      41.0
# 21900  [6.7, 7.8, 11, 8.2, 7.3]      41.0
# 22227  [7.8, 5.3, 11, 8.2, 8.7]      41.0
# 17016  [7.3, 6.7, 11, 7.2, 8.7]      40.9

# %%
# add variables for each letter, by position 
word5["letter1"] = [word[0] for word in word5.word]
word5["letter2"] = [word[1] for word in word5.word]
word5["letter3"] = [word[2] for word in word5.word]
word5["letter4"] = [word[3] for word in word5.word]
word5["letter5"] = [word[4] for word in word5.word]
word5
# Out:
#         word  length  unique_length          letters     vowels  vowel_count  \
# 4000   aires       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12338  arise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 12809  aries       5              5  {r, a, e, i, s}  [a, e, i]            3
# 15519  raise       5              5  {r, a, e, i, s}  [a, e, i]            3
# 1577   siena       5              5  {a, e, n, i, s}  [a, e, i]            3
# ...      ...     ...            ...              ...        ...          ...
# 3972   puppy       5              3        {p, y, u}        [u]            1
# 16727  mummy       5              3        {m, y, u}        [u]            1
# 24887  beebe       5              2           {e, b}        [e]            1
# 15601  mamma       5              2           {a, m}        [a]            1
# 431    ababa       5              2           {a, b}        [a]            1
#
#                       freq_list  freq_sum letter1 letter2 letter3 letter4  \
# 4000   [7.3, 7.8, 11, 8.2, 8.7]      43.0       a       i       r       e
# 12338  [7.3, 7.8, 11, 8.2, 8.7]      43.0       a       r       i       s
# 12809  [7.3, 7.8, 11, 8.2, 8.7]      43.0       a       r       i       e
# 15519  [7.3, 7.8, 11, 8.2, 8.7]      43.0       r       a       i       s
# 1577   [7.8, 11, 7.2, 8.2, 8.7]      42.9       s       i       e       n
# ...                         ...       ...     ...     ...     ...     ...
# 3972            [2.8, 1.6, 3.3]       7.7       p       u       p       p
# 16727           [2.7, 1.6, 3.3]       7.6       m       u       m       m
# 24887                   [11, 2]      13.0       b       e       e       b
# 15601                [7.8, 2.7]      10.5       m       a       m       m
# 431                    [7.8, 2]       9.8       a       b       a       b
#
#       letter5
# 4000        s
# 12338       e
# 12809       s
# 15519       e
# 1577        a
# ...       ...
# 3972        y
# 16727       y
# 24887       e
# 15601       a
# 431         a
#
# [3213 rows x 13 columns]

# %% [markdown]
# ### Solving a Wordle
#
# Working towards a function that can try out a word, get feedback, and work towards the puzzle solution.

# %%
# example: answer = "spare", starting word - "arise"

answer = "spare"
start = "arise"

# %%
# final function! 
def wordle(answer, guess):
    guesses = []
    attempt_no = 1
    words_to_consider = word5.copy()

    while attempt_no <= 6:
        guesses.append(guess)
        if guess == answer:
            print(f"The answer is {guess}, found in attempt number {attempt_no}")
            print(f"Guesses: {guesses}")
            break
        elif attempt_no <= 5: 
            for n in range(0,5):
                col = "letter" + str(n + 1)
                if guess[n] == answer[n]: # letter is in the right place 
                    words_to_consider = words_to_consider[words_to_consider[col] == guess[n]]
                elif guess[n] not in answer: # letter not in the answer
                    words_to_consider = words_to_consider[~words_to_consider.word.str.contains(guess[n])]
                 #   print(f"Dropped words containing {guess[n]}")
                else: # letter is in the answer, but not in the right place 
                    words_to_consider = words_to_consider[words_to_consider.word.str.contains(guess[n])]
                    # and drop words that have this letter in this exact position 
                    words_to_consider = words_to_consider[words_to_consider[col] != guess[n]]
                   # print(f"Filtered to words containing {guess[n]}, but where {col} is not {guess[n]}")
            words_to_consider = words_to_consider.reset_index(drop = True)
          #  print(f"This was attempt {attempt_no}")
            guess = words_to_consider["word"][0]
            attempt_no = attempt_no + 1
        else: 
            print("Sorry, couldn't do it :(")
            print(f"Guesses: {guesses}")

# %%
wordle(answer = "wince", guess = "mince")
# Out:
# The answer is wince, found in attempt number 3
# Guesses: ['mince', 'since', 'wince']

# %%
wordle(answer = "prick", guess = "stuck")
# Out:
# The answer is prick, found in attempt number 3
# Guesses: ['stuck', 'aleck', 'prick']

# %%
wordle(answer = "shire", guess = "brink")
# Out:
# The answer is shire, found in attempt number 4
# Guesses: ['brink', 'raise', 'spire', 'shire']

# %%
wordle(answer = "robot", guess = "brink")
# Out:
# The answer is robot, found in attempt number 4
# Guesses: ['brink', 'sober', 'cobra', 'robot']

# %%
wordle(answer = "robot", guess = "audio")
# Out:
# The answer is robot, found in attempt number 4
# Guesses: ['audio', 'norse', 'rocky', 'robot']

# %% [markdown]
# # Is there a better strategy?
#
# What if, instead of limiting itself by the information returned by a single guess, it tried to maximize the amount of information available from the first two guess by trying two totally different words?

# %%
def wordle_2(answer, guess):
    guesses = []
    attempt_no = 1
    words_to_consider = word5.copy()
    second_word_options = word5.copy()

    while attempt_no <= 6:
        guesses.append(guess)
        if guess == answer:
            print(f"The answer is {guess}, found in attempt number {attempt_no}")
            print(f"Guesses: {guesses}")
            break
        elif attempt_no <= 5: 
            for n in range(0,5):
                col = "letter" + str(n + 1)
                if guess[n] == answer[n]: # letter is in the right place 
                    words_to_consider = words_to_consider[words_to_consider[col] == guess[n]]
                elif guess[n] not in answer: # letter not in the answer
                    words_to_consider = words_to_consider[~words_to_consider.word.str.contains(guess[n])]
                 #   print(f"Dropped words containing {guess[n]}")
                else: # letter is in the answer, but not in the right place 
                    words_to_consider = words_to_consider[words_to_consider.word.str.contains(guess[n])]
                    # and drop words that have this letter in this exact position 
                    words_to_consider = words_to_consider[words_to_consider[col] != guess[n]]
                   # print(f"Filtered to words containing {guess[n]}, but where {col} is not {guess[n]}")
                if attempt_no == 1: 
                    # make it so the second guess will not contain any of the same letters as the first guess 
                    second_word_options = second_word_options[~second_word_options.word.str.contains(guess[n])].reset_index(drop = True)
            words_to_consider = words_to_consider.reset_index(drop = True)
            if attempt_no == 1: 
                # get the next guess 
                guess = second_word_options["word"][0]
            else: 
                guess = words_to_consider["word"][0]
            attempt_no = attempt_no + 1
        else: 
            print("Sorry, couldn't do it :(")
            print(f"Guesses: {guesses}")

# %%
wordle("wince","arise")
# Out:
# The answer is wince, found in attempt number 4
# Guesses: ['arise', 'tinge', 'mince', 'wince']

# %%
wordle_2("wince","arise")
# Out:
# The answer is wince, found in attempt number 4
# Guesses: ['arise', 'count', 'mince', 'wince']

# %%
# test it out on a few 
starting_word = "radio"
answer_set = ["robot","proxy","shire","paint","peace","tangy","stair","route","blend","prick"]

for n in range(0,len(answer_set)):
    print("wordle 1: ")
    wordle(answer_set[n], starting_word)
    print("wordle 2:")
    wordle_2(answer_set[n], starting_word)
# Out:
# wordle 1:
# The answer is robot, found in attempt number 5
# Guesses: ['radio', 'rosen', 'rough', 'rocky', 'robot']
# wordle 2:
# The answer is robot, found in attempt number 3
# Guesses: ['radio', 'csnet', 'robot']
# wordle 1:
# The answer is proxy, found in attempt number 5
# Guesses: ['radio', 'norse', 'grout', 'prowl', 'proxy']
# wordle 2:
# The answer is proxy, found in attempt number 4
# Guesses: ['radio', 'csnet', 'flour', 'proxy']
# wordle 1:
# The answer is shire, found in attempt number 4
# Guesses: ['radio', 'siren', 'spire', 'shire']
# wordle 2:
# The answer is shire, found in attempt number 4
# Guesses: ['radio', 'csnet', 'spire', 'shire']
# wordle 1:
# The answer is paint, found in attempt number 3
# Guesses: ['radio', 'saint', 'paint']
# wordle 2:
# The answer is paint, found in attempt number 3
# Guesses: ['radio', 'csnet', 'paint']
# wordle 1:
# The answer is peace, found in attempt number 4
# Guesses: ['radio', 'least', 'peach', 'peace']
# wordle 2:
# The answer is peace, found in attempt number 4
# Guesses: ['radio', 'csnet', 'place', 'peace']
# wordle 1:
# The answer is tangy, found in attempt number 4
# Guesses: ['radio', 'caste', 'gaunt', 'tangy']
# wordle 2:
# The answer is tangy, found in attempt number 4
# Guesses: ['radio', 'csnet', 'bantu', 'tangy']
# wordle 1:
# The answer is stair, found in attempt number 3
# Guesses: ['radio', 'artie', 'stair']
# wordle 2:
# The answer is stair, found in attempt number 3
# Guesses: ['radio', 'csnet', 'stair']
# wordle 1:
# The answer is route, found in attempt number 3
# Guesses: ['radio', 'rosen', 'route']
# wordle 2:
# The answer is route, found in attempt number 3
# Guesses: ['radio', 'csnet', 'route']
# wordle 1:
# The answer is blend, found in attempt number 3
# Guesses: ['radio', 'spend', 'blend']
# wordle 2:
# The answer is blend, found in attempt number 3
# Guesses: ['radio', 'csnet', 'blend']
# wordle 1:
# The answer is prick, found in attempt number 5
# Guesses: ['radio', 'siren', 'flirt', 'crimp', 'prick']
# wordle 2:
# The answer is prick, found in attempt number 3
# Guesses: ['radio', 'csnet', 'prick']

# %% [markdown]
# # What's the Best Starting words?
#
#
# I'd like to compare a bunch of starting words, get the win rate and the average number of guesses.
#
# I'll need to rewrite my functions a bit, then loop to compile a dataframe of results.

# %%
# rewriting wordle1 function 
def wordle_results(answer, starting_word):
    guess = starting_word
    guesses = []
    attempt_no = 1
    words_to_consider = word5

    while attempt_no <= 6:
        guesses.append(guess)
        if guess == answer:
            success = True
            total_attempts = attempt_no
            break
        elif attempt_no <= 5: 
            for n in range(0,5):
                col = "letter" + str(n + 1)
                if guess[n] == answer[n]: # letter is in the right place 
                    words_to_consider = words_to_consider[words_to_consider[col] == guess[n]]
                elif guess[n] not in answer: # letter not in the answer
                    words_to_consider = words_to_consider[~words_to_consider.word.str.contains(guess[n])]
                else: # letter is in the answer, but not in the right place 
                    words_to_consider = words_to_consider[words_to_consider.word.str.contains(guess[n])]
                    # and drop words that have this letter in this exact position 
                    words_to_consider = words_to_consider[words_to_consider[col] != guess[n]]
            words_to_consider = words_to_consider.reset_index(drop = True)
            guess = words_to_consider["word"][0]
            attempt_no = attempt_no + 1
        else: 
            success = False
            total_attempts = np.NaN
    wordle_method = "method-1"
    result_dict = {"starting_word": starting_word, "answer":answer, "success":success, "attempts":total_attempts,
                  "guesses":list(guesses), "method":wordle_method}
    return pd.DataFrame([result_dict])

# %%
# get a list of 500 random answers to iterate across 
answer_list = list(word5.sample(n= 500, random_state = 12345).word)

# %%
starting_word_list = ["arise", "noise","aisle","least","alien","steal","audio","radio","ouija","pluck"]
starting_word_list_small = ["arise","least","radio","noise","alien"]

# %%
# how many times are we iterating? 
# per answer, per starting word (iterations per method)
len(starting_word_list) * len(answer_list)
# Out:
# 5000

# %%
len(starting_word_list_small) * len(answer_list)
# Out:
# 2500

# %%
# iterate to collect results 

# list to collect dataframe of results 
results = [] 
loopcount = 1
# loop 2500 times
for answer in answer_list:
    for starting_word in starting_word_list:
        wr = wordle_results(answer, starting_word)
        results.append(wr)
        loopcount = loopcount + 1
method1_df = pd.concat(results)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-43-f7e712b7183d> in <module>
#       7 for answer in answer_list:
#       8     for starting_word in starting_word_list:
# ----> 9         wr = wordle_results(answer, starting_word)
#      10         results.append(wr)
#      11         loopcount = loopcount + 1
#
# <ipython-input-27-59c41d932ac3> in wordle_results(answer, starting_word)
#       7
#       8     while attempt_no <= 6:
# ----> 9         guesses.append(guess)
#      10         if guess == answer:
#      11             success = True
#
# MemoryError:

# %%
loopcount
# Out:
# 142

# %%
method1_df = pd.concat(results)

# %% [markdown]
# I keep running into memory errors. Probably from saving a lot of data frames. I should try a different method for saving the results (perhaps a matrix?)

# %%
results
# Out:
# [  starting_word answer  success  attempts  \
#  0         arise  wylie     True         5
#
#                                 guesses    method
#  0  [arise, tinge, movie, julie, wylie]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         noise  wylie     True         5
#
#                                 guesses    method
#  0  [noise, irate, bilge, julie, wylie]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  wylie     True         4  [aisle, loire, julie, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         least  wylie     True         5
#
#                                 guesses    method
#  0  [least, rigel, kline, julie, wylie]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  wylie     True         4  [alien, sidle, julie, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         steal  wylie     True         5
#
#                                 guesses    method
#  0  [steal, loire, bilge, julie, wylie]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         audio  wylie     True         4  [audio, stein, relic, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  wylie     True         4  [radio, stein, julie, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  wylie     True         4  [ouija, risen, tepid, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  wylie     True         4  [pluck, aisle, loire, wylie]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  daisy     True         3  [arise, waist, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  daisy     True         3  [noise, grist, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  daisy     True         3  [aisle, stair, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  daisy     True         3  [least, parsi, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         alien  daisy     True         3  [alien, triad, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  daisy     True         3  [steal, arson, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  daisy     True         3  [audio, diane, daisy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  daisy     True         3  [radio, saudi, daisy]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  daisy     True         4  [ouija, arise, waist, daisy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  daisy     True         4  [pluck, aires, saint, daisy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  strut     True         3  [arise, snort, strut]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  strut     True         4  [noise, strap, strum, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  strut     True         3  [aisle, snort, strut]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  strut     True         3  [least, snort, strut]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  strut     True         4  [alien, torus, strum, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         steal  strut     True         5
#
#                                 guesses    method
#  0  [steal, sting, strop, strum, strut]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         audio  strut     True         4  [audio, cetus, strum, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  strut     True         4  [radio, ernst, spurt, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  strut     True         4  [ouija, cetus, strum, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  strut     True         4  [pluck, suite, snout, strut]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  rumen     True         3  [arise, tenor, rumen]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  rumen     True         4  [noise, arent, under, rumen]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  rumen     True         3  [aisle, tenor, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  rumen     True         3  [least, urine, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         alien  rumen     True         3  [alien, rosen, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  rumen     True         3  [steal, urine, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  rumen     True         3  [audio, nurse, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  rumen     True         3  [radio, runge, rumen]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         ouija  rumen     True         3  [ouija, nurse, rumen]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  rumen     True         4  [pluck, suite, auger, rumen]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         arise  start     True         5
#
#                                 guesses    method
#  0  [arise, sonar, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  start     True         4  [noise, strap, stark, start]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         aisle  start     True         6
#
#                                        guesses    method
#  0  [aisle, trans, roast, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         least  start     True         5
#
#                                 guesses    method
#  0  [least, scant, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         alien  start     True         5
#
#                                 guesses    method
#  0  [alien, roast, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         steal  start     True         4  [steal, stair, stark, start]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         audio  start     True         5
#
#                                 guesses    method
#  0  [audio, snare, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         radio  start     True         5
#
#                                 guesses    method
#  0  [radio, snare, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         ouija  start     True         5
#
#                                 guesses    method
#  0  [ouija, snare, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts  \
#  0         pluck  start     True         6
#
#                                        guesses    method
#  0  [pluck, aires, sonar, smart, swart, start]  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  sault     True         3  [arise, santo, sault]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  sault     True         3  [noise, strap, sault]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         aisle  sault     True         2  [aisle, sault]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         least  sault     True         2  [least, sault]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         alien  sault     True         3  [alien, solar, sault]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  sault     True         3  [steal, slant, sault]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  sault     True         3  [audio, saute, sault]  method-1,
#    starting_word answer  success  attempts  \
#  0         radio  sault     True         5
#
#                                 guesses    method
#  0  [radio, caste, tansy, latus, sault]  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         ouija  sault     True         3  [ouija, saute, sault]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         pluck  sault     True         3  [pluck, louse, sault]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  tenth     True         4  [arise, elton, ghent, tenth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  tenth     True         3  [noise, arent, tenth]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  tenth     True         3  [aisle, tenor, tenth]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  tenth     True         3  [least, tenor, tenth]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  tenth     True         4  [alien, ernst, monte, tenth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         steal  tenth     True         4  [steal, inter, monte, tenth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  tenth     True         3  [audio, ernst, tenth]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  tenth     True         3  [radio, csnet, tenth]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         ouija  tenth     True         3  [ouija, ernst, tenth]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  tenth     True         4  [pluck, aires, monte, tenth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  palsy     True         4  [arise, coast, pansy, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  palsy     True         3  [noise, trash, palsy]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  palsy     True         4  [aisle, snarl, talus, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts         guesses    method
#  0         least  palsy     True         2  [least, palsy]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  palsy     True         4  [alien, solar, talus, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  palsy     True         3  [steal, glans, palsy]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         audio  palsy     True         4  [audio, snare, pabst, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  palsy     True         4  [radio, caste, pansy, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  palsy     True         4  [ouija, snare, pabst, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  palsy     True         4  [pluck, peril, psalm, palsy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  booth     True         4  [arise, count, lofty, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  booth     True         4  [noise, coral, doubt, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  booth     True         4  [aisle, north, mouth, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         least  booth     True         4  [least, turin, botch, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  booth     True         4  [alien, torus, botch, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         steal  booth     True         4  [steal, turin, botch, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         audio  booth     True         4  [audio, norse, botch, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  booth     True         4  [radio, stone, clout, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  booth     True         4  [ouija, norse, botch, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  booth     True         4  [pluck, aires, thong, booth]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  group     True         4  [arise, front, proud, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  group     True         4  [noise, actor, proud, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  group     True         4  [aisle, north, proud, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         least  group     True         3  [least, groin, group]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  group     True         4  [alien, torus, proud, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  group     True         3  [steal, groin, group]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         audio  group     True         4  [audio, rouse, grout, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  group     True         4  [radio, norse, grout, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  group     True         4  [ouija, rouse, grout, group]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         pluck  group     True         3  [pluck, sprue, group]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  ruddy     True         4  [arise, north, blurb, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         noise  ruddy     True         4  [noise, ultra, crump, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  ruddy     True         4  [aisle, north, crump, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         least  ruddy     True         4  [least, groin, burch, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  ruddy     True         4  [alien, torus, crump, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         steal  ruddy     True         4  [steal, groin, burch, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  ruddy     True         3  [audio, nudge, ruddy]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  ruddy     True         3  [radio, ryder, ruddy]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  ruddy     True         4  [ouija, nurse, rutty, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  ruddy     True         4  [pluck, suite, guano, ruddy]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  store     True         3  [arise, snore, store]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         noise  store     True         2  [noise, store]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  store     True         3  [aisle, norse, store]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  store     True         3  [least, stein, store]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         alien  store     True         2  [alien, store]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         steal  store     True         2  [steal, store]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  store     True         3  [audio, norse, store]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  store     True         3  [radio, norse, store]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         ouija  store     True         3  [ouija, norse, store]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  store     True         4  [pluck, aires, ernst, store]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         arise  fraud     True         4  [arise, grant, draco, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  fraud     True         3  [noise, ultra, fraud]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         aisle  fraud     True         4  [aisle, radon, draft, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         least  fraud     True         4  [least, drain, prado, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         alien  fraud     True         4  [alien, roast, guard, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         steal  fraud     True         4  [steal, cairn, prado, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  fraud     True         3  [audio, daunt, fraud]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         radio  fraud     True         4  [radio, tread, grand, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  fraud     True         4  [ouija, saute, urban, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  fraud     True         4  [pluck, suite, urban, fraud]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                guesses    method
#  0         arise  anion     True         3  [arise, amino, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         noise  anion     True         3  [noise, amino, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         aisle  anion     True         3  [aisle, antic, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         least  anion     True         3  [least, cairn, anion]  method-1,
#    starting_word answer  success  attempts         guesses    method
#  0         alien  anion     True         2  [alien, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         steal  anion     True         3  [steal, cairn, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         audio  anion     True         3  [audio, axiom, anion]  method-1,
#    starting_word answer  success  attempts                guesses    method
#  0         radio  anion     True         3  [radio, ilona, anion]  method-1,
#    starting_word answer  success  attempts                       guesses  \
#  0         ouija  anion     True         4  [ouija, cairo, axiom, anion]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts                       guesses  \
#  0         pluck  anion     True         4  [pluck, aires, amino, anion]
#
#       method
#  0  method-1  ,
#    starting_word answer  success  attempts  \
#  0         arise  bound     True         6
#
#                                        guesses    method
#  0  [arise, count, pound, mound, hound, bound]  method-1  ]
